# %%
import os

import tensorflow.compat.v1 as tf

tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\Shadow\anaconda3\envs\DL1\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
X = tf.placeholder(tf.float32,name='x')
Y = tf.placeholder(tf.float32,name='y')

addition = tf.add(X,Y, name="add")

# %%
with tf.Session() as session:
    result = session.run(addition, feed_dict={X:[1], Y:[2]})
    print(result)
# Out:
# [3.]
